# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

conjunto_ratios = pd.DataFrame({
    'ratio_D_basal': [0.218181818,0,0,0,0,0.215384615,0.244186047,0.021505376,0,0.027777778],
    'ratio_D_92h': [3.551724138,1.93877551,7.5625,1.340909091,2.603773585,1.325581395,1.987341772,0.894117647,1.586956522,2.063829787],
    'ratio_D_7d': [0.824561404,1.766666667,0.774193548,0.696202532,1.083333333,1.8125,1.08,1.090909091,0.6,0.347368421],
    'ratio_D_14d': [0.77,0.60,0.33,0.33,0.14,0.11,0.42,0.33,0.46,0.10],
    'ratio_D_28d': [0.06779661,1.704545455,6.526315789,0.170940171,1.236842105,2.322580645,1.342105263,1.214285714,1.222222222,1.895833333],
    'slip_ratio_basal': [0.07,0.00,0.00,0.00,0.29,0.06,0.00,0.13,0.14,0.00],
    'slip_ratio_92h': [1.00,1.00,0.90,0.72,0.38,0.70,0.64,0.65,1.00,0.85],
    'slip_ratio_7d': [0.81,1.00,0.83,0.75,0.89,1.00,0.57,0.57,0.89,0.94],
    'slip_ratio_14d': [0.888888889,0.444444444,0.166666667,0.125,0.285714286,0.375,0.625,0.75,0.6875,0.625],
    'slip_ratio_28d': [0.21,0.22,0.85,0.00,0.93,1.00,0.88,0.79,1.00,1.00]
})

print("The DataFrame of Employees is:")
print(conjunto_ratios, "\n")

corr_df = conjunto_ratios.corr(method='spearman')
plt.figure(figsize=(8, 6))
sns.heatmap(corr_df, annot=True)
plt.show()
corr_df.style.background_gradient(cmap='coolwarm')
# Out:
# The DataFrame of Employees is:
#    ratio_D_basal  ratio_D_92h  ratio_D_7d  ratio_D_14d  ratio_D_28d  \
# 0       0.218182     3.551724    0.824561         0.77     0.067797
# 1       0.000000     1.938776    1.766667         0.60     1.704545
# 2       0.000000     7.562500    0.774194         0.33     6.526316
# 3       0.000000     1.340909    0.696203         0.33     0.170940
# 4       0.000000     2.603774    1.083333         0.14     1.236842
# 5       0.215385     1.325581    1.812500         0.11     2.322581
# 6       0.244186     1.987342    1.080000         0.42     1.342105
# 7       0.021505     0.894118    1.090909         0.33     1.214286
# 8       0.000000     1.586957    0.600000         0.46     1.222222
# 9       0.027778     2.063830    0.347368         0.10     1.895833
#
#    slip_ratio_basal  slip_ratio_92h  slip_ratio_7d  slip_ratio_14d  \
# 0              0.07            1.00           0.81        0.888889
# ...
